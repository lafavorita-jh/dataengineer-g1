# %%
print("Hola mundo")

# %%
cantidad: int = 3
precio: float = 145.0
cliente: str = "Marco Torres"
activo: bool = True
descuento: float | None = None

# %%
print(cantidad)
print(descuento)
# Out:
# 3
# None
